# %%
# 操作 browser 的 API
from selenium.webdriver.chrome.service import Service
from selenium import webdriver

# 處理逾時例外的工具
from selenium.common.exceptions import TimeoutException

# 面對動態網頁，等待某個元素出現的工具，通常與 exptected_conditions 搭配
from selenium.webdriver.support.ui import WebDriverWait

# 搭配 WebDriverWait 使用，對元素狀態的一種期待條件，若條件發生，則等待結束，往下一行執行
from selenium.webdriver.support import expected_conditions as EC

# 期待元素出現要透過什麼方式指定，通常與 EC、WebDriverWait 一起使用
from selenium.webdriver.common.by import By

# 強制等待 (執行期間休息一下)
from time import sleep

import csv

# send_keys模擬鍵盤輸入
from selenium.webdriver.common.keys import Keys

import random

import re 


# 啟動瀏覽器工具的選項
my_options = webdriver.ChromeOptions()
# my_options.add_argument("--headless")                #不開啟實體瀏覽器背景執行
my_options.add_argument("--start-maximized")         #最大化視窗
my_options.add_argument("--incognito")               #開啟無痕模式
my_options.add_argument("--disable-popup-blocking") #禁用彈出攔截
my_options.add_argument("--disable-notifications")  #取消 chrome 推播通知
my_options.add_argument("--lang=zh-TW")  #設定為正體中文

# 使用 Chrome 的 WebDriver
driver = webdriver.Chrome(
    options = my_options
)

# 放置爬取的資料
dataset = [['id', 'name', 'star', 'comment', 'class', 'coordinate', 'address', 'sunday_06', 'sunday_07', 'sunday_08', 'sunday_09', 'sunday_10', 'sunday_11', 'sunday_12', 'sunday_13', 'sunday_14', 'sunday_15', 'sunday_16', 'sunday_17', 'sunday_18', 'sunday_19', 'sunday_20', 'sunday_21', 'sunday_22', 'sunday_23', 'monday_06', 'monday_07', 'monday_08', 'monday_09', 'monday_10', 'monday_11', 'monday_12', 'monday_13', 'monday_14', 'monday_15', 'monday_16', 'monday_17', 'monday_18', 'monday_19', 'monday_20', 'monday_21', 'monday_22', 'monday_23', 'tuesday_06', 'tuesday_07', 'tuesday_08', 'tuesday_09', 'tuesday_10', 'tuesday_11', 'tuesday_12', 'tuesday_13', 'tuesday_14', 'tuesday_15', 'tuesday_16', 'tuesday_17', 'tuesday_18', 'tuesday_19', 'tuesday_20', 'tuesday_21', 'tuesday_22', 'tuesday_23', 'wednesday_06', 'wednesday_07', 'wednesday_08', 'wednesday_09', 'wednesday_10', 'wednesday_11', 'wednesday_12', 'wednesday_13', 'wednesday_14', 'wednesday_15', 'wednesday_16', 'wednesday_17', 'wednesday_18', 'wednesday_19', 'wednesday_20', 'wednesday_21', 'wednesday_22', 'wednesday_23', 'thursday_06', 'thursday_07', 'thursday_08', 'thursday_09', 'thursday_10', 'thursday_11', 'thursday_12', 'thursday_13', 'thursday_14', 'thursday_15', 'thursday_16', 'thursday_17', 'thursday_18', 'thursday_19', 'thursday_20', 'thursday_21', 'thursday_22', 'thursday_23', 'friday_06', 'friday_07', 'friday_08', 'friday_09', 'friday_10', 'friday_11', 'friday_12', 'friday_13', 'friday_14', 'friday_15', 'friday_16', 'friday_17', 'friday_18', 'friday_19', 'friday_20', 'friday_21', 'friday_22', 'friday_23', 'saturday_06', 'saturday_07', 'saturday_08', 'saturday_09', 'saturday_10', 'saturday_11', 'saturday_12', 'saturday_13', 'saturday_14', 'saturday_15', 'saturday_16', 'saturday_17', 'saturday_18', 'saturday_19', 'saturday_20', 'saturday_21', 'saturday_22', 'saturday_23']]

# %%
driver.get('https://www.google.com/maps?authuser=0')

# 尋找網頁中的搜尋框
# inputElement = driver.find_element(By.CSS_SELECTOR, 'input#ikeyword')
input_block = driver.find_element(
    By.CSS_SELECTOR,
    'input.searchboxinput.xiQnY'
)

# 在搜尋框中輸入文字
input_block.send_keys("大安區 飲料店")
sleep(0.1)
input_block.send_keys(Keys.ENTER)
sleep(0.5)






def scroll():
    innerHeight = 0
    offset = 0
    count = 0
    start = True

    #google_map，JS動態變化前標籤
    inner_frame = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.CSS_SELECTOR, "div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd"))
    )
    
    
    offset = driver.execute_script(
            '''return document.querySelector('div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd').scrollHeight;'''
        )
    
    #使用 JavaScript 來捲動內部視窗的滾動條 
    driver.execute_script(f'''
            document.querySelector("div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd").scrollTo({{
                top: {offset},
                behavior: 'smooth'
            }});
        ''')
    
    sleep(1)
    
    while start :
        
        offset = driver.execute_script(
                "return document.querySelector('div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd.QjC7t').scrollHeight;"
            )
        print(offset)
        
        #google_map，JS動態變化後標籤
        inner_frame = WebDriverWait(driver, 10).until(
            EC.presence_of_element_located((By.CSS_SELECTOR, "div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd.QjC7t"))
        )
        
        #使用 JavaScript 來捲動內部視窗的滾動條 
        driver.execute_script(f'''
                document.querySelector("div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd.QjC7t").scrollTo({{
                    top: {offset},
                    behavior: 'smooth'
                }});
            ''')
    
        #強制休息
        sleep(random.randrange(4))

        
        inner_height = driver.execute_script(
               '''return document.querySelector('div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd').scrollHeight;'''
            )
        print(inner_height)

        #網頁滾到最底，結束程式
        if inner_height == offset:
            count += 1
            if count == 6:
                sleep(10)
        else :
            count = 0
        print(count)
        
        if count == 10:
            start = False

#執行測試
scroll()
# Out:
# 3285
# 3285
# 1
# 3285
# 4899
# 0
# 4899
# 6565
# 0
# 6565
# 6565
# 1
# 6565
# 8295
# 0
# 8295
# 10017
# 0
# 10017
# 10017
# 1
# 10017
# 11700
# 0
# 11720
# 11700
# 0
# 11680
# 11680
# 1
# 11680
# 13306
# 0
# 13306
# 13306
# 1
# 13306
# 13306
# 2
# 13306
# 13306
# 3
# 13306
# 13306
# 4
# 13306
# 13306
# 5
# 13306
# 13306
# 6
# 13306
# 13306
# 7
# 13306
# 13306
# 8
# 13306
# 13306
# 9
# 13306
# 13306
# 10

# %%
b = [f'sunday_{i:02d}' for i in range(6,24)]
print(b)
b = [f'monday_{i:02d}' for i in range(6,24)]
print(b)
b = [f'tuesday_{i:02d}' for i in range(6,24)]
print(b)
b = [f'wednesday_{i:02d}' for i in range(6,24)]
print(b)
b = [f'thursday_{i:02d}' for i in range(6,24)]
print(b)
b = [f'friday_{i:02d}' for i in range(6,24)]
print(b)
b = [f'saturday_{i:02d}' for i in range(6,24)]
print(b)
# Out:
# ['sunday_06', 'sunday_07', 'sunday_08', 'sunday_09', 'sunday_10', 'sunday_11', 'sunday_12', 'sunday_13', 'sunday_14', 'sunday_15', 'sunday_16', 'sunday_17', 'sunday_18', 'sunday_19', 'sunday_20', 'sunday_21', 'sunday_22', 'sunday_23']
# ['monday_06', 'monday_07', 'monday_08', 'monday_09', 'monday_10', 'monday_11', 'monday_12', 'monday_13', 'monday_14', 'monday_15', 'monday_16', 'monday_17', 'monday_18', 'monday_19', 'monday_20', 'monday_21', 'monday_22', 'monday_23']
# ['tuesday_06', 'tuesday_07', 'tuesday_08', 'tuesday_09', 'tuesday_10', 'tuesday_11', 'tuesday_12', 'tuesday_13', 'tuesday_14', 'tuesday_15', 'tuesday_16', 'tuesday_17', 'tuesday_18', 'tuesday_19', 'tuesday_20', 'tuesday_21', 'tuesday_22', 'tuesday_23']
# ['wednesday_06', 'wednesday_07', 'wednesday_08', 'wednesday_09', 'wednesday_10', 'wednesday_11', 'wednesday_12', 'wednesday_13', 'wednesday_14', 'wednesday_15', 'wednesday_16', 'wednesday_17', 'wednesday_18', 'wednesday_19', 'wednesday_20', 'wednesday_21', 'wednesday_22', 'wednesday_23']
# ['thursday_06', 'thursday_07', 'thursday_08', 'thursday_09', 'thursday_10', 'thursday_11', 'thursday_12', 'thursday_13', 'thursday_14', 'thursday_15', 'thursday_16', 'thursday_17', 'thursday_18', 'thursday_19', 'thursday_20', 'thursday_21', 'thursday_22', 'thursday_23']
# ['friday_06', 'friday_07', 'friday_08', 'friday_09', 'friday_10', 'friday_11', 'friday_12', 'friday_13', 'friday_14', 'friday_15', 'friday_16', 'friday_17', 'friday_18', 'friday_19', 'friday_20', 'friday_21', 'friday_22', 'friday_23']
# ['saturday_06', 'saturday_07', 'saturday_08', 'saturday_09', 'saturday_10', 'saturday_11', 'saturday_12', 'saturday_13', 'saturday_14', 'saturday_15', 'saturday_16', 'saturday_17', 'saturday_18', 'saturday_19', 'saturday_20', 'saturday_21', 'saturday_22', 'saturday_23']

# %%
# 取得google_map基本內容
elements = driver.find_elements(
    By.CSS_SELECTOR,
    'div.UaQhfb.fontBodyMedium '
)

id = 0 #店家id

for elm in elements:
    #店家id
    id += 1

    #店家名稱
    name = elm.find_element(
        By.CSS_SELECTOR,
        'div.qBF1Pd.fontHeadlineSmall '
    )
    
    #店家種類
    shop_class = elm.find_elements(
        By.CSS_SELECTOR,
        'div.W4Efsd > div.W4Efsd > span'
    )

    #有些店家沒有評論數、星數，直接給數值為0
    no_commend = elm.find_element(
        By.CSS_SELECTOR,
        'span.e4rVHe.fontBodyMedium'
    )

    if no_commend.text == '沒有評論':

        dataset.append([id, name.text, 0, 0, shop_class[0].text])
        continue

    #星數
    star = elm.find_element(
        By.CSS_SELECTOR,
        'span.MW4etd'
    )

    #評論數
    comment_num = elm.find_element(
        By.CSS_SELECTOR,
        'span.UY7F9'
    )
    
    regex_comment = r"\w+" #(60) => 60
    comment_num_re = re.search(regex_comment, comment_num.text)

    #資料匯入list
    dataset.append([id, name.text, eval(star.text), eval(comment_num_re[0]), shop_class[0].text])


print(dataset)
# Out:
# [['id', 'name', 'star', 'comment', 'class', 'coordinate', 'address', 'sunday_06', 'sunday_07', 'sunday_08', 'sunday_09', 'sunday_10', 'sunday_11', 'sunday_12', 'sunday_13', 'sunday_14', 'sunday_15', 'sunday_16', 'sunday_17', 'sunday_18', 'sunday_19', 'sunday_20', 'sunday_21', 'sunday_22', 'sunday_23', 'monday_06', 'monday_07', 'monday_08', 'monday_09', 'monday_10', 'monday_11', 'monday_12', 'monday_13', 'monday_14', 'monday_15', 'monday_16', 'monday_17', 'monday_18', 'monday_19', 'monday_20', 'monday_21', 'monday_22', 'monday_23', 'tuesday_06', 'tuesday_07', 'tuesday_08', 'tuesday_09', 'tuesday_10', 'tuesday_11', 'tuesday_12', 'tuesday_13', 'tuesday_14', 'tuesday_15', 'tuesday_16', 'tuesday_17', 'tuesday_18', 'tuesday_19', 'tuesday_20', 'tuesday_21', 'tuesday_22', 'tuesday_23', 'wednesday_06', 'wednesday_07', 'wednesday_08', 'wednesday_09', 'wednesday_10', 'wednesday_11', 'wednesday_12', 'wednesday_13', 'wednesday_14', 'wednesday_15', 'wednesday_16', 'wednesday_17', 'wednesday_18', 'wednesday_19', 'wednesday_20', 'wednesday_21', 'wednesday_22', 'wednesday_23', 'thursday_06', 'thursday_07', 'thursday_08', 'thursday_09', 'thursday_10', 'thursday_11', 'thursday_12', 'thursday_13', 'thursday_14', 'thursday_15', 'thursday_16', 'thursday_17', 'thursday_18', 'thursday_19', 'thursday_20', 'thursday_21', 'thursday_22', 'thursday_23', 'friday_06', 'friday_07', 'friday_08', 'friday_09', 'friday_10', 'friday_11',
手搖飲料專賣店', 3.5, 145, '冰品飲料店'], [35, 'COFFEE.TEA.OR - 敦南概念店', 4.6, 765, '冰品飲料店'], [36, '吾悠茶所', 4.8, 718, '冰品飲料店'], [37, '先喝道台北東區大安店', 4.1, 60, '冰品飲料店'], [38, '波哥的小處茶堂', 3.7, 237, '冰品飲料店'], [39, '富士堂-日本鮮奶茶飲專門店', 4.7, 375, '冰品飲料店'], [40, '易水寒-大安本店', 4.5, 276, '冰品飲料店'], [41, 'CoCo都可 台北建國店', 4.4, 369, '冰品飲料店'], [42, 'CHOW CHOW早午餐|下午茶|冰品|氣泡飲|大安厚蛋吐司|人氣冰店|必吃冰店|熱門剉冰|必吃甜品|在地推薦冰店', 4.9, 42, '冰品飲料店'], [43, '天下佈武日月潭紅茶', 3.7, 831, '冰品飲料店'], [44, '時時飲', 3.6, 5, '冰品飲料店'], [45, '春山茶水舖', 4.5, 1, '冰品飲料店'], [46, '麻古茶坊大安復興店', 4.1, 143, '冰品飲料店'], [47, '冇月冇日 冰萃茶茶飲專賣店', 4.9, 281, '冰品飲料店'], [48, '方最茗品 和平店', 4.3, 241, '冰品飲料店'], [49, '茶號枱', 4.2, 44, '冰品飲料店'], [50, '大安新生59(朝顏的部屋)', 4.3, 9, '冰品飲料店'], [51, 'Futi Fudi 果滴滴 延吉店-大安必喝果汁|新鮮果汁|外帶手搖飲|水果調飲|平價果汁|新鮮果茶', 4.5, 365 ...

# %%
#取得各店家連結、經緯度
list_links = []

links = driver.find_elements(
    By.CSS_SELECTOR,
    'a.hfpxzc'
)

id = 0

for lelm in links:
    #店家連結
    id += 1
    link = lelm.get_attribute('href')
    list_links.append(link)

    #coordinate(經緯度)
    regex_coordinate = r"(?<=!3d).*(?=!16s)" #link => 25.0266645!4d121.5431999
    search_coordinate = re.search(regex_coordinate, link)
    coordinate = search_coordinate[0].replace('!4d',',') #coordinate:座標(經緯度)

    #加入list
    dataset[id].append(coordinate)

# %%
# 將 list 存成 csv

with open(f"./大安區.csv", "w", newline='', encoding="utf-8-sig") as file:
    w = csv.writer(file)
    # 寫入二維表格
    w.writerows(dataset)

# %%
#進入店家連結取得詳細資料
id = 0

for url in list_links:

    driver.get(url)

    id += 1
    #店家名稱(測試用)
    name = driver.find_element(
        By.CSS_SELECTOR,
        'h1.DUwDvf.lfPIob'
    )
    print(name.text)

    #詳細地址
    address = driver.find_element(
        By.CSS_SELECTOR,
        'div.Io6YTe.fontBodyMedium.kR99db '
    )

    regex_address = r"(?<=\w{3}).+" #106台北市大安區復興南路二段206號 => 台北市大安區復興南路二段206號
    search_address = re.search(regex_address, address.text)
    print(search_address[0])
    #加入list
    dataset[id].append(search_address[0])

    #熱門時段
    crowd = driver.find_elements(
        By.CSS_SELECTOR,
        'div.dpoVLd  '
    ) #hour:06~23
    print(len(crowd))
    #無熱門時段店家
    if crowd == []:
        continue

    # crowd_week = driver.find_element(
    #     By.CSS_SELECTOR,
    #     'div.t39EBf.GUrTXd'
    # )
    # crowd_week = crowd_week.get_attribute('aria-label')

    # # print(crowd_week)

    # regex_crowd = r'.{3}(?=、休息)' #星期日
    # findall_crowd = re.findall(regex_crowd, crowd_week)
    
    # if len(findall_crowd) != 0:
    #     print(findall_crowd)
    try:
        WebDriverWait(driver, 1).until(
            EC.presence_of_element_located((By.CSS_SELECTOR, "div.c3RoDe > span"))
        )

        holiday = driver.find_element(
            By.CSS_SELECTOR,
           'div.c3RoDe > span'
        )
        
        print(holiday.text)
        
        #0-17:sunday、18-35:monday、36-53:tuesday、54-71:wednesday、72-89:thursday、90-107:friday、108-125:saturday
        week = {'星期日':[i for i in range(0,18)], '星期一':[i for i in range(18,36)],
                '星期二':[i for i in range(36,54)], '星期三':[i for i in range(54,72)],
                '星期四':[i for i in range(72,90)], '星期五':[i for i in range(90,108)],
                '星期六':[i for i in range(108,126)]}
        
        # for i in range(0,len(crowd)):
        #     if i == 0:
        #         time = crowd[i].get_attribute('aria-label')
        #         regex_time = r"\w+(?=%)" #'6時 時的繁忙程度通常為 0%。' => 0
        #         search_time = re.search(regex_time,time)      
        #         dataset.append([eval(search_time[0])])
        
        #     else:
        #         time = crowd[i].get_attribute('aria-label')
        #         regex_time = r"\w+(?=%)" #'6時 時的繁忙程度通常為 0%。' => 0
        #         search_time = re.search(regex_time,time)      
        #         dataset[id].append(eval(search_time[0])) 
    except TimeoutException:
        print('無公休日')
    finally:
        pass

print(dataset)
# Out:
# 幸福搖搖-西門1號店
# 台北市萬華區成都路54號1樓
# 126
# 無公休日
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 6
#       2 id = 0
#       4 for url in list_links:
# ----> 6     driver.get(url)
#       8     id += 1
#       9     #店家名稱(測試用)
#
# File ~\anaconda3\envs\web_scraping\lib\site-packages\selenium\webdriver\remote\webdriver.py:356, in WebDriver.get(self, url)
#     354 def get(self, url: str) -> None:
#     355     """Loads a web page in the current browser session."""
# --> 356     self.execute(Command.GET, {"url": url})
#
# File ~\anaconda3\envs\web_scraping\lib\site-packages\selenium\webdriver\remote\webdriver.py:345, in WebDriver.execute(self, driver_command, params)
#     342     elif "sessionId" not in params:
#     343         params["sessionId"] = self.session_id
# --> 345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
#     347     self.error_handler.check_response(response)
#
# File ~\anaconda3\envs\web_scraping\lib\site-packages\selenium\webdriver\remote\remote_connection.py:300, in RemoteConnection.execute(self, command, params)
#     298 data = utils.dump_json(params)
#     299 url = f"{self._url}{path}"
# --> 300 return self._request(command_info[0], url, body=data)
#
# File ~\anaconda3\envs\web_scraping\lib\site-packages\selenium\webdriver\remote\remote_connection.py:321, in RemoteConnection._request(self, method, url, body)
#     318     body = None
#     320 if self.keep_alive:
# --> 321     response = self._conn.request(method, url, body=body, headers=headers)
#     322     statuscode = response.status
#     323 else:
#
# File ~\anaconda3\envs\web_scraping\lib\site-packages\urllib3\request.py:81, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      77     return self.request_encode_url(
#      78         method, url, fields=fields, headers=headers, **urlopen_kw
#      79     )
#      80 else:
# ---> 81     return self.request_encode_body(
#      82         method, url, fields=fields, headers=headers, **urlopen_kw
#      83     )
#
# File ~\anaconda3\envs\web_scraping\lib\site-packages\urllib3\request.py:173, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     170 extra_kw["headers"].update(headers)
#     171 extra_kw.update(urlopen_kw)
# --> 173 return self.urlopen(method, url, **extra_kw)
#
# File ~\anaconda3\envs\web_scraping\lib\site-packages\urllib3\poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File ~\anaconda3\envs\web_scraping\lib\site-packages\urllib3\connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712     self._prepare_proxy(conn)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#     729 response_conn = conn if not release_conn else None
#
# File ~\anaconda3\envs\web_scraping\lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462             httplib_response = conn.getresponse()
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     469     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\envs\web_scraping\lib\site-packages\urllib3\connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     459 except TypeError:
#     460     # Python 3
#     461     try:
# --> 462         httplib_response = conn.getresponse()
#     463     except BaseException as e:
#     464         # Remove the TypeError from the exception chain in
#     465         # Python 3 (including for exceptions like SystemExit).
#     466         # Otherwise it looks like a bug in the code.
#     467         six.raise_from(e, None)
#
# File ~\anaconda3\envs\web_scraping\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~\anaconda3\envs\web_scraping\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\anaconda3\envs\web_scraping\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\anaconda3\envs\web_scraping\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
driver.get('https://www.google.com/maps/place/%E8%87%BA%E5%8C%97%E8%9E%A2%E6%A9%8B%E9%83%B5%E5%B1%80/@25.0246362,121.5173895,17z/data=!3m1!4b1!4m6!3m5!1s0x3442a997069d478b:0x5051303462bd833f!8m2!3d25.0246362!4d121.5173895!16s%2Fg%2F12m9cjvc6?authuser=0&hl=zh-TW&entry=ttu')


WebDriverWait(driver, 10).until(
    EC.presence_of_element_located((By.CSS_SELECTOR, "div.c3RoDe > span"))
    )
close = driver.find_elements(
    By.CSS_SELECTOR,
    'div.c3RoDe > span'
    )

close[0].text
print(123)
# Out:
# 123

# %%
i = 1

if i in [1,2,3]:
    print(123)
# Out:
# 123

# %%
# 操作 browser 的 API
from selenium.webdriver.chrome.service import Service
from selenium import webdriver

# 處理逾時例外的工具
from selenium.common.exceptions import TimeoutException

# 面對動態網頁，等待某個元素出現的工具，通常與 exptected_conditions 搭配
from selenium.webdriver.support.ui import WebDriverWait

# 搭配 WebDriverWait 使用，對元素狀態的一種期待條件，若條件發生，則等待結束，往下一行執行
from selenium.webdriver.support import expected_conditions as EC

# 期待元素出現要透過什麼方式指定，通常與 EC、WebDriverWait 一起使用
from selenium.webdriver.common.by import By

# 強制等待 (執行期間休息一下)
from time import sleep

import csv

# send_keys模擬鍵盤輸入
from selenium.webdriver.common.keys import Keys

import random

import re

def initialize_browser():
    # 啟動瀏覽器工具的選項
    my_options = webdriver.ChromeOptions()
    # my_options.add_argument("--headless")                #不開啟實體瀏覽器背景執行
    my_options.add_argument("--start-maximized")         #最大化視窗
    my_options.add_argument("--incognito")               #開啟無痕模式
    my_options.add_argument("--disable-popup-blocking") #禁用彈出攔截
    my_options.add_argument("--disable-notifications")  #取消 chrome 推播通知
    my_options.add_argument("--lang=zh-TW")  #設定為正體中文

    # 使用 Chrome 的 WebDriver
    driver = webdriver.Chrome(
        options = my_options
    )

    return driver


def input_name(driver, search_name):
    # 前往google_map網站
    driver.get('https://www.google.com/maps?authuser=0')

    # 尋找網頁中的搜尋框
    input_block = driver.find_element(
        By.CSS_SELECTOR,
        'input.searchboxinput.xiQnY'
    )
    print(f'{search_name}-starting...')
    # 在搜尋框中輸入文字
    input_block.send_keys(f'{search_name} 飲料店')
    sleep(0.1)
    input_block.send_keys(Keys.ENTER)
    sleep(0.5)


def scroll(driver):
    innerHeight = 0
    offset = 0
    count = 0
    start = True

    # google_map，JS動態變化前標籤
    inner_frame = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located(
            (By.CSS_SELECTOR, "div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd"))
    )

    offset = driver.execute_script(
        '''return document.querySelector('div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd').scrollHeight;'''
    )

    # 使用 JavaScript 來捲動內部視窗的滾動條
    driver.execute_script(f'''
            document.querySelector("div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd").scrollTo({{
                top: {offset},
                behavior: 'smooth'
            }});
        ''')

    sleep(1)

    while start:

        offset = driver.execute_script(
            "return document.querySelector('div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd.QjC7t').scrollHeight;"
        )

        # google_map，JS動態變化後標籤
        inner_frame = WebDriverWait(driver, 10).until(
            EC.presence_of_element_located((By.CSS_SELECTOR, "div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd.QjC7t"))
        )

        # 使用 JavaScript 來捲動內部視窗的滾動條
        driver.execute_script(f'''
                document.querySelector("div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd.QjC7t").scrollTo({{
                    top: {offset},
                    behavior: 'smooth'
                }});
            ''')

        # 強制休息
        sleep(random.randrange(4))

        inner_height = driver.execute_script(
            '''return document.querySelector('div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd').scrollHeight;'''
        )


        # 網頁滾到最底，結束程式
        if inner_height == offset:
            if count in [4, 6, 8]:
                sleep(10)
                
                # 往回滾動，重新loading...
                offset = -50
                driver.execute_script(f'''
                    document.querySelector("div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd.QjC7t").scrollBy({{
                        top: {offset},
                        behavior: 'smooth'
                        }});
                    ''')
            count += 1
        else:
            count = 0

        if count == 10:
            start = False


def scraping(driver):
    # 放置爬取的資料
    dataset = [['id', 'name', 'star', 'comment', 'class', 'coordinate', 'address']]

    # 取得google_map基本內容
    elements = driver.find_elements(
        By.CSS_SELECTOR,
        'div.UaQhfb.fontBodyMedium '
    )

    id = 0  # 店家id

    for elm in elements:
        # 店家id
        id += 1

        # 店家名稱
        name = elm.find_element(
            By.CSS_SELECTOR,
            'div.qBF1Pd.fontHeadlineSmall '
        )

        # 店家種類
        shop_class = elm.find_elements(
            By.CSS_SELECTOR,
            'div.W4Efsd > div.W4Efsd > span'
        )

        # 有些店家沒有評論數、星數，直接給數值為0
        no_commend = elm.find_element(
            By.CSS_SELECTOR,
            'span.e4rVHe.fontBodyMedium'
        )

        if no_commend.text == '沒有評論':
            dataset.append([id, name.text, 0, 0, shop_class[0].text])
            continue

        # 星數
        star = elm.find_element(
            By.CSS_SELECTOR,
            'span.MW4etd'
        )

        # 評論數
        comment_num = elm.find_element(
            By.CSS_SELECTOR,
            'span.UY7F9'
        )

        regex_comment = r"\w+"  # (60) => 60
        comment_num_re = re.search(regex_comment, comment_num.text)

        # 資料匯入list
        dataset.append([id, name.text, eval(star.text), eval(comment_num_re[0]), shop_class[0].text])


    # 取得各店家連結、經緯度
    list_links = [] # 存放店家連結

    links = driver.find_elements(
        By.CSS_SELECTOR,
        'a.hfpxzc'
    )

    id = 0

    for lelm in links:
        # 店家連結
        id += 1
        link = lelm.get_attribute('href')
        list_links.append(link)

        # coordinate(經緯度)
        regex_coordinate = r"(?<=!3d).*(?=!16s)"  # link => 25.0266645!4d121.5431999
        search_coordinate = re.search(regex_coordinate, link)
        coordinate = search_coordinate[0].replace('!4d', ',')  # coordinate:座標(經緯度)

        # 經緯度加入list
        dataset[id].append(coordinate)

    # 進入店家連結取得詳細資料
    id = 0

    for url in list_links:
        driver.get(url)

        # 強制休息
        sleep(random.randrange(4))
        
        id += 1

        # 詳細地址
        address = driver.find_element(
            By.CSS_SELECTOR,
            'div.Io6YTe.fontBodyMedium.kR99db '
        )

        regex_address = r"[^0-9].*"  # 106台北市大安區復興南路二段206號 => 台北市大安區復興南路二段206號
        search_address = re.search(regex_address, address.text)
        # 加入list
        dataset[id].append(search_address[0])

    return dataset

def to_csv(search_name, dataset):
    # 將 list 存成 csv
    with open(f"./{search_name}.csv", "w", newline='', encoding="utf-8-sig") as file:
        w = csv.writer(file)
        # 寫入二維表格
        w.writerows(dataset)
        print(f'{search_name}-ending...')

if __name__ == "__main__":
    driver = initialize_browser()

    with open(r'./dist_test.txt', 'r', encoding='utf-8') as file:
        dist_list = file.read().split('、')  # 行政區
        for search_name in dist_list:
            search_name = search_name.strip() # 去除字串頭尾空格
            input_name(driver, search_name)
            scroll(driver)
            dataset = scraping(driver)
            to_csv(search_name, dataset)
            

    driver.quit()
# Out:
# 松山區-starting...
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[8], line 256
#     254 search_name = search_name.strip() # 去除字串頭尾空格
#     255 input_name(driver, search_name)
# --> 256 scroll(driver)
#     257 dataset = scraping(driver)
#     258 to_csv(search_name, dataset)
#
# Cell In[8], line 124, in scroll(driver)
#     122         # 往回滾動
#     123         offset = -50
# --> 124         driver.execute_script(f'''
#     125             document.querySelector("div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd.QjC7t").scrollBy({{
#     126                 top: {offset},
#     127                 behavior: 'smooth'
#     128                 }});
#     129             ''')
#     130     count += 1
#     131 else:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\selenium\webdriver\remote\webdriver.py:407, in WebDriver.execute_script(self, script, *args)
#     404 converted_args = list(args)
#     405 command = Command.W3C_EXECUTE_SCRIPT
# --> 407 return self.execute(command, {"script": script, "args": converted_args})["value"]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~\AppData\Roaming\Python\Python310\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=120.0.6099.225)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6557D2142+3514994]
# 	(No symbol) [0x00007FF6553F0CE2]
# 	(No symbol) [0x00007FF6552976AA]
# 	(No symbol) [0x00007FF655270AFD]
# 	(No symbol) [0x00007FF65530CB1B]
# 	(No symbol) [0x00007FF65532218F]
# 	(No symbol) [0x00007FF655305D93]
# 	(No symbol) [0x00007FF6552D4BDC]
# 	(No symbol) [0x00007FF6552D5C64]
# 	GetHandleVerifier [0x00007FF6557FE16B+3695259]
# 	GetHandleVerifier [0x00007FF655856737+4057191]
# 	GetHandleVerifier [0x00007FF65584E4E3+4023827]
# 	GetHandleVerifier [0x00007FF6555204F9+689705]
# 	(No symbol) [0x00007FF6553FC048]
# 	(No symbol) [0x00007FF6553F8044]
# 	(No symbol) [0x00007FF6553F81C9]
# 	(No symbol) [0x00007FF6553E88C4]
# 	BaseThreadInitThunk [0x00007FFE582F7344+20]
# 	RtlUserThreadStart [0x00007FFE585626B1+33]

# %%
with open(r'./dist_test.txt', 'r', encoding='utf-8') as file:
        dist_list = file.read().split('、')  # 行政區
        for search_name in dist_list:
            print(search_name)
            if search_name == "松山區":
                print(123)
# Out:
# 松山區
# 123
# 信義區

# %%
# 操作 browser 的 API
from selenium.webdriver.chrome.service import Service
from selenium import webdriver

# 處理逾時例外的工具
from selenium.common.exceptions import TimeoutException

# 面對動態網頁，等待某個元素出現的工具，通常與 exptected_conditions 搭配
from selenium.webdriver.support.ui import WebDriverWait

# 搭配 WebDriverWait 使用，對元素狀態的一種期待條件，若條件發生，則等待結束，往下一行執行
from selenium.webdriver.support import expected_conditions as EC

# 期待元素出現要透過什麼方式指定，通常與 EC、WebDriverWait 一起使用
from selenium.webdriver.common.by import By

# 強制等待 (執行期間休息一下)
from time import sleep

import csv

# send_keys模擬鍵盤輸入
from selenium.webdriver.common.keys import Keys

import random

import re

# listening
import pyautogui
from time import sleep, time
import keyboard
from IPython.display import clear_output

# 多執行緒
import threading



def initialize_browser():
    # 啟動瀏覽器工具的選項
    my_options = webdriver.ChromeOptions()
    # my_options.add_argument("--headless")                #不開啟實體瀏覽器背景執行
    my_options.add_argument("--start-maximized")         #最大化視窗
    my_options.add_argument("--incognito")               #開啟無痕模式
    my_options.add_argument("--disable-popup-blocking") #禁用彈出攔截
    my_options.add_argument("--disable-notifications")  #取消 chrome 推播通知
    my_options.add_argument("--lang=zh-TW")  #設定為正體中文

    # 使用 Chrome 的 WebDriver
    driver = webdriver.Chrome(
        options = my_options
    )

    return driver


def input_name(driver, search_name):
    # 前往google_map網站
    driver.get('https://www.google.com/maps?authuser=0')

    # 尋找網頁中的搜尋框
    input_block = driver.find_element(
        By.CSS_SELECTOR,
        'input.searchboxinput.xiQnY'
    )
    print(f'{search_name}-starting...')
    # 在搜尋框中輸入文字
    input_block.send_keys(f'{search_name} 飲料店')
    sleep(0.1)
    input_block.send_keys(Keys.ENTER)
    sleep(0.5)


def scroll(driver):
    innerHeight = 0
    offset = 0
    count = 0
    start = True

    # google_map，JS動態變化前標籤
    inner_frame = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located(
            (By.CSS_SELECTOR, "div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd"))
    )

    offset = driver.execute_script(
        '''return document.querySelector('div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd').scrollHeight;'''
    )

    # 使用 JavaScript 來捲動內部視窗的滾動條
    driver.execute_script(f'''
            document.querySelector("div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd").scrollTo({{
                top: {offset},
                behavior: 'smooth'
            }});
        ''')

    sleep(1)

    while start:

        offset = driver.execute_script(
            "return document.querySelector('div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd.QjC7t').scrollHeight;"
        )

        # google_map，JS動態變化後標籤
        inner_frame = WebDriverWait(driver, 10).until(
            EC.presence_of_element_located((By.CSS_SELECTOR, "div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd.QjC7t"))
        )

        # 使用 JavaScript 來捲動內部視窗的滾動條
        driver.execute_script(f'''
                document.querySelector("div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd.QjC7t").scrollTo({{
                    top: {offset},
                    behavior: 'smooth'
                }});
            ''')

        # 強制休息
        sleep(random.randrange(4))

        inner_height = driver.execute_script(
            '''return document.querySelector('div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd').scrollHeight;'''
        )


        # 網頁滾到最底，結束程式
        if inner_height == offset:
            if count in [4, 6]:
                sleep(5)
                
                # 往回滾動，重新loading...
                offset = -50
                driver.execute_script(f'''
                    document.querySelector("div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd.QjC7t").scrollBy({{
                        top: {offset},
                        behavior: 'smooth'
                        }});
                    ''')
            count += 1
        else:
            count = 0

        if count == 10:
            start = False


def scraping(driver):
    # 放置爬取的資料
    dataset = [['id', 'name', 'star', 'comment', 'class', 'coordinate', 'address']]

    # 取得google_map基本內容
    elements = driver.find_elements(
        By.CSS_SELECTOR,
        'div.UaQhfb.fontBodyMedium '
    )

    id = 0  # 店家id

    for elm in elements:
        # 店家id
        id += 1

        # 店家名稱
        name = elm.find_element(
            By.CSS_SELECTOR,
            'div.qBF1Pd.fontHeadlineSmall '
        )

        # 店家種類
        shop_class = elm.find_elements(
            By.CSS_SELECTOR,
            'div.W4Efsd > div.W4Efsd > span'
        )

        # 有些店家沒有評論數、星數，直接給數值為0
        no_commend = elm.find_element(
            By.CSS_SELECTOR,
            'span.e4rVHe.fontBodyMedium'
        )

        if no_commend.text == '沒有評論':
            dataset.append([id, name.text, 0, 0, shop_class[0].text])
            continue

        # 星數
        star = elm.find_element(
            By.CSS_SELECTOR,
            'span.MW4etd'
        )

        # 評論數
        comment_num = elm.find_element(
            By.CSS_SELECTOR,
            'span.UY7F9'
        )

        regex_comment = r"\w+"  # (60) => 60
        comment_num_re = re.search(regex_comment, comment_num.text)

        # 資料匯入list
        dataset.append([id, name.text, eval(star.text), eval(comment_num_re[0]), shop_class[0].text])


    # 取得各店家連結、經緯度
    list_links = [] # 存放店家連結

    links = driver.find_elements(
        By.CSS_SELECTOR,
        'a.hfpxzc'
    )

    id = 0

    for lelm in links:
        # 店家連結
        id += 1
        link = lelm.get_attribute('href')
        list_links.append(link)

        # coordinate(經緯度)
        regex_coordinate = r"(?<=!3d).*(?=!16s)"  # link => 25.0266645!4d121.5431999
        search_coordinate = re.search(regex_coordinate, link)
        coordinate = search_coordinate[0].replace('!4d', ',')  # coordinate:座標(經緯度)

        # 經緯度加入list
        dataset[id].append(coordinate)

    # 進入店家連結取得詳細資料
    id = 0

    for url in list_links:
        driver.get(url)

        # 強制休息
        sleep(random.randrange(4))
        
        id += 1

        # 詳細地址
        # address = driver.find_element(
        #     By.CSS_SELECTOR,
        #     'div.Io6YTe.fontBodyMedium.kR99db '
        # )
        address = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located(
            (By.CSS_SELECTOR, "div.Io6YTe.fontBodyMedium.kR99db"))
        )

        regex_address = r'[^0-9].*'  # 106台北市大安區復興南路二段206號 => 台北市大安區復興南路二段206號
        search_address = re.search(regex_address, address.text)
        
        # 加入list
        dataset[id].append(search_address[0])

    return dataset

def to_csv(search_name, dataset):
    # 將 list 存成 csv
    with open(f"./{search_name}.csv", "w", newline='', encoding="utf-8-sig") as file:
        w = csv.writer(file)
        # 寫入二維表格
        w.writerows(dataset)
        print(f'{search_name}-ending...')

def listening():
    global switch

    while switch:
        # 睡一下
        sleep(0.01)

        #自動清除此格的文字輸出
        clear_output(wait=True)

        try:
            # 取得 Box 物件
            btn_reload = pyautogui.locateOnScreen(
                './reload.png',
                confidence=0.9 # opencv信心指數，用 1 的話圖片一點灰塵污漬都不能有 
            )
            # 輸出
            print(btn_reload)

            btn_reload_point = pyautogui.center(btn_reload)

            # 按下 重新載入
            pyautogui.click(btn_reload_point.x, btn_reload_point.y)
        except:
            pass

if __name__ == "__main__":
    driver = initialize_browser()
    switch = True
    listening_thread = threading.Thread(target=listening)
    listening_thread.start()

    with open(r'./dist_test.txt', 'r', encoding='utf-8') as file:
        dist_list = file.read().split('、')  # 行政區
        for search_name in dist_list:
            search_name = search_name.strip() # 去除字串頭尾空格
            input_name(driver, search_name)
            scroll(driver)
            dataset = scraping(driver)
            to_csv(search_name, dataset)
            
    switch = False # 爬蟲結束，結束監聽   
    listening_thread.join() # 等待監聽線程结束
    
    driver.quit()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 305
#     303         input_name(driver, search_name)
#     304         scroll(driver)
# --> 305         dataset = scraping(driver)
#     306         to_csv(search_name, dataset)
#     308 switch = False # 爬蟲結束，結束監聽
#
# Cell In[1], line 237, in scraping(driver)
#     234 driver.get(url)
#     236 # 強制休息
# --> 237 sleep(random.randrange(4))
#     239 id += 1
#     241 # 詳細地址
#     242 # address = driver.find_element(
#     243 #     By.CSS_SELECTOR,
#     244 #     'div.Io6YTe.fontBodyMedium.kR99db '
#     245 # )
#
# KeyboardInterrupt:

# %%
import pandas as pd
import glob

# 指定存放CSV文件的資料夾路徑
folder_path = r'C:/Users/USER/Desktop/大區'  # 確保使用r來避免轉義字符的問題

# 使用glob模塊找出匹配指定模式的所有CSV文件路徑
csv_files = glob.glob(folder_path + "/*.csv")


# 初始化一個空的列表來存儲每個文件的DataFrame
dfs = []

# 遍歷找到的CSV文件路徑，讀取每個文件，並將其追加到列表中
for filename in csv_files:
    print(filename)
    df = pd.read_csv(filename)

    df = df.drop('id', axis=1)

    print('ok')
    dfs.append(df)

# 使用concat函數合併所有DataFrame
all_data = pd.concat(dfs, ignore_index=True)

# 刪除重複行
# 指定要檢查重複值的列名
columns_to_check = ['name', 'star', 'comment', 'class']
# 刪除指定列組合重複的行，keep='first'表示保留第一次出現的行
all_data = all_data.drop_duplicates(subset=columns_to_check, keep='first')

# 留下class特定的值
selected_values = ['冰品飲料店', '無酒精飲料店', '珍珠奶茶', '果汁', '飲料', '飲品分銷商']
filtered_df = all_data[all_data['class'].isin(selected_values)]

# 拆分 coordinate 列
filtered_df[['latitude', 'longitude']] = filtered_df['coordinate'].str.split(',', expand=True)
# expand=True允許將拆分的結果作為多個列添加到DF中，而不只是一個列表或Series。

# 删除原始 coordinate 列
filtered_df.drop('coordinate', axis=1, inplace=True)
# inplace=True直接修改原始DF

# 顯示合併後的數據
# print(filtered_df)

# 如果需要，可以將合併後的DataFrame存儲到新的CSV文件中
filtered_df.to_csv('./merged_data.csv', index=False, encoding='utf-8-sig')
# Out:
# C:/Users/USER/Desktop/大區\台北市內湖區五分里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區內湖里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區內溝里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區大湖里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區安泰里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區安湖里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區康寧里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區明湖里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區東湖里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區樂康里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區清白里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區港墘里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區港富里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區港華里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區港都里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區湖元里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區湖濱里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區湖興里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區瑞光里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區瑞陽里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區石潭里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區碧山里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區秀湖里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區紫星里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區紫陽里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區紫雲里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區葫洲里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區蘆洲里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區行善里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區西安里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區西康里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區西湖里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區週美里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區金湖里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區金瑞里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區金龍里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市內湖區麗山里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市士林區仁勇里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市士林區前港里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市士林區富光里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市士林區富洲里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市士林區後港里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市士林區承德里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市士林區明勝里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市士林區永倫里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市士林區百齡里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市士林區社園里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市士林區社子里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市士林區社新里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市士林區福中里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市士林區福佳里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市士林區福安里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市士林區福德里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市士林區福志里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市士林區福林里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市士林區福華里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市士林區福順里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市士林區義信里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市士林區舊佳里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市士林區葫東里.csv
# ok
# C:/Users/USER/Desktop/大區\台北市士林區葫蘆里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區中興里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區仁德里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區保安里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區保新里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區保長里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區信望里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區八連里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區北山里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區北峰里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區厚德里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區城中里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區大同里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區宜興里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區山光里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區崇德里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區康福里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區建成里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區復興里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區忠孝里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區忠山里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區拱北里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區文化里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區新昌里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區智慧里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區東勢里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區東山里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區樟樹里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區橋東里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區橫科里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區江北里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區湖光里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區湖興里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區湖蓮里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區烘內里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區環河里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區白雲里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區福安里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區福山里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區福德里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區禮門里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區秀山里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區秀峰里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區義民里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區自強里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區興福里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區茄苳里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區鄉長里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區金龍里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區長安里.csv
# ok
# C:/Users/USER/Desktop/大區\新北市汐止區長青里.csv
# ok
# C:\Users\USER\AppData\Local\Temp\ipykernel_96056\3294762021.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df[['latitude', 'longitude']] = filtered_df['coordinate'].str.split(',', expand=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_96056\3294762021.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df[['latitude', 'longitude']] = filtered_df['coordinate'].str.split(',', expand=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_96056\3294762021.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.drop('coordinate', axis=1, inplace=True)

# %%
filtered_df[filtered_df['address'].str.len()>2]
# Out:
#                                                    name  star  comment  \
# 0                                     五桐號WooTea 台北內湖東湖店   2.4       86
# 1                                              50嵐 東湖二店   4.1      208
# 2                                   泰讚了thai like tea東湖店   3.7       53
# 3                                             水巷茶弄台北東湖店   4.1      132
# 4                                               麻古茶坊東湖店   3.2      119
# 5                                                沫家Moga   4.2       45
# 6                                            武林茶東湖麥琪喵喵店   3.7       36
# 7                                        Mr. Wish 台北東湖店   4.1       63
# 8                                         無飲-東湖店(現萃茶專賣）   4.6       37
# 9                                              四季紅茶冰東湖店   3.9       50
# 10                                            清心福全內湖東湖店   4.3       88
# 11                    日秋紅白調飲 Chillin'day 起始店 【紅茶歐蕾手搖專賣】   4.8      219
# 12                                                綠農健康舖   3.2       25
# 13                                         好了啦紅茶冰－內湖康寧店   3.7        3
# 14                                                 舞茶玩味   5.0       13
# 15                                            黑丸嫩仙草 東湖店   4.0      312
# 16                                            丰玉蜂蜜‧飲品專門   4.6      120
# 17                                                  慕茶客   4.1       52
# 18                                                 拾弄叁號   4.7       49
# 19                                              50嵐 東湖店   3.9      311
# 20                                           CoCo都可 康寧店   4.2      128
# 21                                        COMEBUY_台北葫洲店   3.7       89
# 22               森井冰舖 東湖（純手工熬煮配料/天然食材/黑糖/剉冰/豆花/紅豆湯/燒仙草）   4.2       91
# 23                                             搞茗堂古早味茶飲   4.0       32
# 24                                           大碗公冰店(東湖店)   3.8      417
# 25                                            冰菓蹦-台北葫洲店   4.5       20
# 26                                         茶聚CHAGE內湖康寧店   4.1      123
# 27                                       T.TEA ｜ 新鮮原萃茶飲   5.0       61
# 28                                            研果室-台北內湖店   4.8      603
# 29                                        COMEBUY_台北內湖店   3.4      192
# 30                                             武林茶內湖成功店   3.3       88
# 31                                 龍角 Dragon Horn 內湖成功店   4.4      139
# 32                                              閑茗樓 內湖店   4.7      178
# 33                                      五桐號WooTea 台北內湖店   3.9       82
# 34                                        杜芳子古味茶鋪-內湖成功店   3.7       94
# 35                                        再睡5分鐘 - 台北江南店   4.7      856
# 36                                          麻古茶坊內湖科學園區店   3.5      587
# 37                                    山焙 SUNBAY (內湖科技店）   4.2      317
# 38                                         糖糖茶飲專賣店（新明店）   4.4       24
# 39                                             茶湯會內湖江南店   3.9      165
# 40                                            七盞茶 內湖江南店   4.3      133
# 41                                                  萊樂檬   4.6      193
# 42                                          Spica手作太空飲品   4.4      144
# 43                                            50嵐 內湖園區店   3.2      251
# 44                                   署茗職茶@AtTea 台北內湖旗艦店   2.7      169
# 45                                      TrueWin初韻 台北內湖店   4.7      525
# 46                          萬波島嶼紅茶 Wanpo Tea Shop 內湖港墘店   3.3       77
# 47                                            一沐日 內湖江南店   3.8      568
# 48                                        LAG 累擱鮮奶茶 內湖店   4.4       25
# 49                                            珍煮丹 內湖江南店   3.8      701
# 50                                        COMEBUY_台北西湖店   3.6      133
# 51                                    食字路口 | 西瓜汁 黑糖珍珠奶茶   4.4       57
# 52                                      TEA TOP 第一味 內湖店   4.6      236
# 53                                                嚮家涼水鋪   4.4      203
# 55                                       degugu果果迪（西湖店）   4.4       45
# 56                                           二口旅茶｜台北西湖店   4.8      327
# 58                                             拾汣茶屋 西湖店   3.9      625
# 62                                茶曉伊 Tea Know You 茶飲專賣   4.2      121
# 63             沁茶悦東湖店/內湖飲料/內湖茶飲/內湖冷飲/內湖Drink/內湖飲品/內湖手搖杯   4.0       84
# 68                                                 吾飲良品   4.4       65
# 71                                               柯達 燒仙草   4.2      106
# 72                                                 教練冰店   4.2      160
# 73                                           龜記茗品-內湖康寧店   4.1       74
# 74                                           清心福全 內湖碧湖店   3.9       85
# 75                                       coco都可茶飲（內湖金龍）   4.8      108
# 76                                              50嵐 德安店   3.9      199
# 77                                              麻古茶坊康寧店   4.0       98
# 79                                              烏弄內湖港墘店   4.1      131
# 80                                              老茶人 內科店   4.4      168
# 81                                 鬍子茶Who's Tea - 內湖文德店   4.4       86
# 83                                            木衛二 內湖鑄茶所   4.0       36
# 84                                            老賴茶棧台北內湖店   3.3       69
# 85                                        柔屋冰品 UO House   4.7      504
# 86                              香草山上 Mountain of Spices   4.7       15
# 88                                     壺茶車 Pot Tea King   3.6      108
# 90                       Hollly Shake 賀雪莉 美式奶昔專賣店 台北內湖店   4.5       27
# 92                                                小雨季茗舖   4.2       53
# 96                                             龜記茗品 內湖店   3.7      224
# 100                                   樂法 Le Phare - 三總店   3.5       90
# 102                                      微堂well done內湖店   4.6       67
# 103                                           希堤佐席 台灣茶飲   4.1       18
# 104                          華山藏窖人文茶飲內湖店 瑞光宏匯廣場 t.Hub一樓   4.1       93
# 108                                                  銘鋪   0.0        0
# 111                                           珍煮丹 內湖園區店   4.5      270
# 113                                          CoCo都可 內湖店   3.8      156
# 114                               青芽摘CHING YA TEA 台北西湖店   3.7       83
# 115                                      清玉手調原味茶（台北西湖店）   3.0       83
# 118                                           珍煮丹 內湖江南店   3.8      701
# 120                                   五桐號WooTea 台北內湖江南店   3.4      108
# 121                                             發發 港墘牧場   4.7      470
# 123                                           得正#內湖江南計劃   3.7      100
# 125                                      一手私藏世界紅茶 內湖西湖店   4.1       79
# 127                                              約翰紅茶公司   4.4        1
# 128                                       可不可熟成紅茶-內湖瑞光店   3.6      109
# 130                                         茗芋坊Taro Tea   4.9      205
# 134                     柑單生活坊-鮮果氣泡飲、咖啡、Q餅(鬆餅)、飲料 下午茶 外送   4.8       39
# 135                             來唄·來杯 Give me a cup 文德店   4.9       51
# 136                                       Mr. Wish台北西湖店   3.8      132
# 139                                 Drink Store水雲朵內科洲子店   4.3       44
# 141                                       可不可熟成紅茶-內湖江南店   3.6      142
# 142                                          空杯國際 - 內湖店   2.7      127
# 143                                           鮮芋仙 台北內湖店   3.2      175
# 144                                              鹿飲LUIN   4.3       50
# 145                                            糖水間湯圓專賣店   4.0      508
# 147                                           秀茶邸家(內湖店)   4.6       31
# 148                             布鹿‧果漾新鮮式Blue deer(江南總店)   4.1      190
# 149                                          清原芋圓 內湖瑞光店   4.8        1
# 150                                    迷客夏Milksha 臺北西湖店   3.9      217
# 6062   冰品飲料店  25.0023804,121.6190507                         新北市深坑區埔新街92號
# 6065   冰品飲料店  25.0037649,121.6016696                      新北市深坑區北深路三段190號
# 6067   冰品飲料店     25.0036239,121.6015                      新北市深坑區北深路三段181號
# 6161  無酒精飲料店  25.0511366,121.6178603                         新北市汐止區橫科路12號
# 6162  無酒精飲料店  25.0468692,121.6265849                      新北市汐止區橫科路500-3號
# 6520    珍珠奶茶  25.0549991,121.6137943                      台北市南港區南港路一段147號
# 6524   冰品飲料店  25.0343203,121.5663022                     台北市信義區松智路17號 號B2
# 6525   冰品飲料店    25.045578,121.581159                        台北市南港區永吉路543號
# 6527   冰品飲料店   25.043253,121.5686279                   台北市信義區永吉路30巷112號1樓
# 6529   冰品飲料店   25.037449,121.5791328                         台北市信義區林口街29號
# 6530   冰品飲料店    25.037061,121.578198              No, No. 574松山路信義區台北市110
# 6554    珍珠奶茶  25.0612059,121.6272464                     新北市汐止區福德一路392巷9號
# 6637   冰品飲料店  25.0688853,121.6577562                        新北市汐止區中正路236號
# 6965   冰品飲料店  25.0554038,121.6120312                    台北市南港區南港路一段162號1樓
# 6967   冰品飲料店    25.0554834,121.61369                    台北市南港區南港路一段116號1樓
# 6973   冰品飲料店    25.068164,121.637964                       新北市汐止區福德一路105號

# %%
#顯示所有列
pd.set_option('display.max_columns', None)
#顯示所有行
pd.set_option('display.max_rows', None)

all_data

unique_values = all_data['class'].unique()
print(unique_values)

# 特定值的行
# 留下class特定的值
selected_values = ['冰品飲料店', '無酒精飲料店', '珍珠奶茶', '果汁', '飲料', '飲品分銷商']
filtered_df = all_data[all_data['class'].isin(selected_values)]


filtered_df

filtered_df[filtered_df['address'].str.len()>=6]
# Out:
# ['冰品飲料店' '無酒精飲料店' '早餐' '公園' '早午餐' '火鍋' '咖啡廳' '點心' '珍珠奶茶' '甜品店' '熟食店'
#  '中式茶館' '餐廳' '闔家皆宜料理' '果汁' '韓國菜' '景點' '政府辦事處' '114台北市內湖區' nan '公車站' '咖啡店'
#  '意大利菜' '公司辦公室' '健康食品專賣店' '茶葉店' '拉麵' '沙律' '小吃店' '便利店' '鄉鎮市區公所' '地方政府辦事處'
#  '日式糖果店' '健康食品' '中國菜' '炸物串與串炸餐廳' '社區中心' '娛樂中心' '區域政府辦事處' '泰國菜' '牛丼餐廳'
#  '大眾運輸站' '飲料' '快餐' '日本菜' '美國菜' '法式薄餅' '餃子' '111台北市士林區' '居酒屋' '冷麵店' '遊艇碼頭'
#  '神壇' '飲品分銷商' '港式茶餐廳' '地方政府機構' '長者中心' '小學' '煎餅' '嚴格素食料理' '麵店' '正宗日式料理'
#  '公廁' '涮涮鍋' '小食/零食吧' '傳統市場' '日式咖哩' '壽司' '區政府辦公室' '外帶咖啡專賣店' '221新北市汐止區'
#  '連排房屋社區' '公寓社區' '商店' '寺廟' '表演場地' '非牟利組織' '食品製造商' '台灣菜' '籃球場' '雜貨店' '康樂'
#  '旅遊景點' '意式薄餅' '各種意大利麵' '串燒烤肉店' '超級市場']
#                                                    name  star  comment  \
# 0                                     五桐號WooTea 台北內湖東湖店   2.4       86
# 1                                              50嵐 東湖二店   4.1      208
# 2                                   泰讚了thai like tea東湖店   3.7       53
# 3                                             水巷茶弄台北東湖店   4.1      132
# 4                                               麻古茶坊東湖店   3.2      119
# 5                                                沫家Moga   4.2       45
# 6                                            武林茶東湖麥琪喵喵店   3.7       36
# 7                                        Mr. Wish 台北東湖店   4.1       63
# 8                                         無飲-東湖店(現萃茶專賣）   4.6       37
# 9                                              四季紅茶冰東湖店   3.9       50
# 10                                            清心福全內湖東湖店   4.3       88
# 11                    日秋紅白調飲 Chillin'day 起始店 【紅茶歐蕾手搖專賣】   4.8      219
# 12                                                綠農健康舖   3.2       25
# 13                                         好了啦紅茶冰－內湖康寧店   3.7        3
# 14                                                 舞茶玩味   5.0       13
# 15                                            黑丸嫩仙草 東湖店   4.0      312
# 16                                            丰玉蜂蜜‧飲品專門   4.6      120
# 17                                                  慕茶客   4.1       52
# 18                                                 拾弄叁號   4.7       49
# 19                                              50嵐 東湖店   3.9      311
# 20                                           CoCo都可 康寧店   4.2      128
# 21                                        COMEBUY_台北葫洲店   3.7       89
# 22               森井冰舖 東湖（純手工熬煮配料/天然食材/黑糖/剉冰/豆花/紅豆湯/燒仙草）   4.2       91
# 23                                             搞茗堂古早味茶飲   4.0       32
# 24                                           大碗公冰店(東湖店)   3.8      417
# 25                                            冰菓蹦-台北葫洲店   4.5       20
# 26                                         茶聚CHAGE內湖康寧店   4.1      123
# 27                                       T.TEA ｜ 新鮮原萃茶飲   5.0       61
# 28                                            研果室-台北內湖店   4.8      603
# 29                                        COMEBUY_台北內湖店   3.4      192
# 30                                             武林茶內湖成功店   3.3       88
# 31                                 龍角 Dragon Horn 內湖成功店   4.4      139
# 32                                              閑茗樓 內湖店   4.7      178
# 33                                      五桐號WooTea 台北內湖店   3.9       82
# 34                                        杜芳子古味茶鋪-內湖成功店   3.7       94
# 35                                        再睡5分鐘 - 台北江南店   4.7      856
# 36                                          麻古茶坊內湖科學園區店   3.5      587
# 37                                    山焙 SUNBAY (內湖科技店）   4.2      317
# 38                                         糖糖茶飲專賣店（新明店）   4.4       24
# 39                                             茶湯會內湖江南店   3.9      165
# 40                                            七盞茶 內湖江南店   4.3      133
# 41                                                  萊樂檬   4.6      193
# 42                                          Spica手作太空飲品   4.4      144
# 43                                            50嵐 內湖園區店   3.2      251
# 44                                   署茗職茶@AtTea 台北內湖旗艦店   2.7      169
# 45                                      TrueWin初韻 台北內湖店   4.7      525
# 46                          萬波島嶼紅茶 Wanpo Tea Shop 內湖港墘店   3.3       77
# 47                                            一沐日 內湖江南店   3.8      568
# 48                                        LAG 累擱鮮奶茶 內湖店   4.4       25
# 49                                            珍煮丹 內湖江南店   3.8      701
# 50                                        COMEBUY_台北西湖店   3.6      133
# 51                                    食字路口 | 西瓜汁 黑糖珍珠奶茶   4.4       57
# 52                                      TEA TOP 第一味 內湖店   4.6      236
# 53                                                嚮家涼水鋪   4.4      203
# 55                                       degugu果果迪（西湖店）   4.4       45
# 56                                           二口旅茶｜台北西湖店   4.8      327
# 6530   冰品飲料店    25.037061,121.578198              No, No. 574松山路信義區台北市110
# 6554    珍珠奶茶  25.0612059,121.6272464                     新北市汐止區福德一路392巷9號
# 6637   冰品飲料店  25.0688853,121.6577562                        新北市汐止區中正路236號
# 6965   冰品飲料店  25.0554038,121.6120312                    台北市南港區南港路一段162號1樓
# 6967   冰品飲料店    25.0554834,121.61369                    台北市南港區南港路一段116號1樓
# 6973   冰品飲料店    25.068164,121.637964                       新北市汐止區福德一路105號

# %%
pd.read_csv('C:/Users/USER/Desktop/士林區/台北市士林區仁勇里.csv')
# Out:
#       id                name  star  comment  class              coordinate  \
# 0      1     TrueWin初韻 士林文林店   4.8        1  冰品飲料店  25.0895149,121.5270062
# 1      2  苡諾愛喝茶YINO DRINKING   4.6       35  冰品飲料店  25.0871994,121.5253874
# 2      3              綠杯杯飲料店   5.0        1  冰品飲料店  25.0881175,121.5259768
# 3      4             台灣涼茶基河店   0.0        0  冰品飲料店  25.0866221,121.5248648
# 4      5     泰愛了 手工泰式奶茶 士林總店   4.9      270  冰品飲料店  25.0894221,121.5243592
# ..   ...                 ...   ...      ...    ...                     ...
# 101  102                家湘涼麵   3.0        1    冷麵店    25.089341,121.525041
# 102  103        刨冰研究所 士林官邸冰店   4.9      228  冰品飲料店  25.0971742,121.5328851
# 103  104         丰明水秀果茶殿 福國店   4.8      327  冰品飲料店    25.102248,121.523942
# 104  105     福氣塘HOKI TEA延平門市   4.8       38  冰品飲料店  25.0886292,121.5080441
# 105  106             士林店 丼の物   4.9       80    日本菜  25.0886246,121.5260684
#
#                 address
# 0         台北市士林區文林路176號
# 1           台北市士林區大東路8號
# 2     台北市士林區文林路101巷2號前面
# 3         台北市士林區基河路9號之1
# 4          台北市士林區大南路85號
# ..                  ...
# 101        台北市士林區大南路46號
# 102     台北市士林區福林路197號1樓
# 103        台北市士林區福國路44號
# 104  台北市士林區延平北路六段123號1樓
# 105         台北市士林區小東街2號
#
# [106 rows x 7 columns]

# %%
df = pd.DataFrame([[1, 2], [3, 4]], columns=list('AB'), index=['x', 'y'])
df2 = pd.DataFrame([[5, 6], [7, 8]], columns=list('AB'), index=['x', 'y'])
df.append(df2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 3
#       1 df = pd.DataFrame([[1, 2], [3, 4]], columns=list('AB'), index=['x', 'y'])
#       2 df2 = pd.DataFrame([[5, 6], [7, 8]], columns=list('AB'), index=['x', 'y'])
# ----> 3 df.append(df2)
#
# File ~\anaconda3\envs\web_scraping\lib\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
# 創建第一個DataFrame
df1 = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})

# 創建第二個DataFrame
df2 = pd.DataFrame({'A': [5, 6], 'B': [7, 8]})

# 使用concat函數將它們合併
result = pd.concat([df1, df2])

print(result)
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 0  5  7
# 1  6  8

# %%
import pandas as pd
import glob

# 指定存放CSV文件的資料夾路徑
folder_path = r'C:/Users/USER/Desktop/士林區'  # 確保使用r來避免轉義字符的問題

# 使用glob模塊找出匹配指定模式的所有CSV文件路徑
csv_files = glob.glob(folder_path + "/*.csv")
print(csv_files[0])
pd.read_csv(csv_files[4],engine='python')
# Out:
# C:/Users/USER/Desktop/士林區\台北市士林區仁勇里.csv
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[53], line 10
#       8 csv_files = glob.glob(folder_path + "/*.csv")
#       9 print(csv_files[0])
# ---> 10 pd.read_csv(csv_files[4],engine='python')
#
# File ~\anaconda3\envs\web_scraping\lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\envs\web_scraping\lib\site-packages\pandas\io\parsers\readers.py:617, in _read(filepath_or_buffer, kwds)
#     614     return parser
#     616 with parser:
# --> 617     return parser.read(nrows)
#
# File ~\anaconda3\envs\web_scraping\lib\site-packages\pandas\io\parsers\readers.py:1748, in TextFileReader.read(self, nrows)
#    1741 nrows = validate_integer("nrows", nrows)
#    1742 try:
#    1743     # error: "ParserBase" has no attribute "read"
#    1744     (
#    1745         index,
#    1746         columns,
#    1747         col_dict,
# -> 1748     ) = self._engine.read(  # type: ignore[attr-defined]
#    1749         nrows
#    1750     )
#    1751 except Exception:
#    1752     self.close()
#
# File ~\anaconda3\envs\web_scraping\lib\site-packages\pandas\io\parsers\python_parser.py:286, in PythonParser.read(self, rows)
#     283     indexnamerow = content[0]
#     284     content = content[1:]
# --> 286 alldata = self._rows_to_cols(content)
#     287 data, columns = self._exclude_implicit_index(alldata)
#     289 conv_data = self._convert_data(data)
#
# File ~\anaconda3\envs\web_scraping\lib\site-packages\pandas\io\parsers\python_parser.py:1058, in PythonParser._rows_to_cols(self, content)
#    1052             reason = (
#    1053                 "Error could possibly be due to quotes being "
#    1054                 "ignored when a multi-char delimiter is used."
#    1055             )
#    1056             msg += ". " + reason
# -> 1058         self._alert_malformed(msg, row_num + 1)
#    1060 # see gh-13320
#    1061 zipped_content = list(lib.to_object_array(content, min_width=col_len).T)
#
# File ~\anaconda3\envs\web_scraping\lib\site-packages\pandas\io\parsers\python_parser.py:779, in PythonParser._alert_malformed(self, msg, row_num)
#     762 """
#     763 Alert a user about a malformed row, depending on value of
#     764 `self.on_bad_lines` enum.
#    (...)
#     776     even though we 0-index internally.
#     777 """
#     778 if self.on_bad_lines == self.BadLineHandleMethod.ERROR:
# --> 779     raise ParserError(msg)
#     780 if self.on_bad_lines == self.BadLineHandleMethod.WARN:
#     781     base = f"Skipping line {row_num}: "
#
# ParserError: Expected 7 fields in line 104, saw 8

# %%
# 操作 browser 的 API
from selenium.webdriver.chrome.service import Service
from selenium import webdriver

# 處理逾時例外的工具
from selenium.common.exceptions import TimeoutException

# 面對動態網頁，等待某個元素出現的工具，通常與 exptected_conditions 搭配
from selenium.webdriver.support.ui import WebDriverWait

# 搭配 WebDriverWait 使用，對元素狀態的一種期待條件，若條件發生，則等待結束，往下一行執行
from selenium.webdriver.support import expected_conditions as EC

# 期待元素出現要透過什麼方式指定，通常與 EC、WebDriverWait 一起使用
from selenium.webdriver.common.by import By

# 強制等待 (執行期間休息一下)
from time import sleep

import csv

# send_keys模擬鍵盤輸入
from selenium.webdriver.common.keys import Keys

import random

import re

# listening
import pyautogui
from time import sleep, time
import keyboard
from IPython.display import clear_output

# 多執行緒
import threading



def initialize_browser():
    # 啟動瀏覽器工具的選項
    my_options = webdriver.ChromeOptions()
    # my_options.add_argument("--headless")                #不開啟實體瀏覽器背景執行
    my_options.add_argument("--start-maximized")         #最大化視窗
    my_options.add_argument("--incognito")               #開啟無痕模式
    my_options.add_argument("--disable-popup-blocking") #禁用彈出攔截
    my_options.add_argument("--disable-notifications")  #取消 chrome 推播通知
    my_options.add_argument("--lang=zh-TW")  #設定為正體中文

    # 使用 Chrome 的 WebDriver
    driver = webdriver.Chrome(
        options = my_options
    )

    return driver


def input_name(driver, search_name):
    # 前往google_map網站
    driver.get('https://www.google.com/maps?authuser=0')

    # 尋找網頁中的搜尋框
    input_block = driver.find_element(
        By.CSS_SELECTOR,
        'input.searchboxinput.xiQnY'
    )
    print(f'{search_name}-starting...')
    # 在搜尋框中輸入文字
    input_block.send_keys(f'{search_name} 火車站')
    sleep(0.1)
    input_block.send_keys(Keys.ENTER)
    sleep(0.5)




def scraping(driver):
    # 放置爬取的資料
    dataset = [['id', 'name', 'star', 'comment', 'class', 'coordinate', 'address']]
    
    try:
        # 取得google_map基本內容
        elements = driver.find_elements(
            By.CSS_SELECTOR,
            'div.UaQhfb.fontBodyMedium'
        )

        id = 0  # 店家id

        for elm in elements:
            # 店家id
            id += 1

            # 店家名稱
            name = elm.find_element(
                By.CSS_SELECTOR,
                'div.qBF1Pd.fontHeadlineSmall'
            )

            # 店家種類
            shop_class = elm.find_elements(
                By.CSS_SELECTOR,
                'div.W4Efsd > div.W4Efsd > span'
            )

            # 有些店家沒有評論數、星數，直接給數值為0
            no_commend = elm.find_element(
                By.CSS_SELECTOR,
                'span.e4rVHe.fontBodyMedium'
            )

            if no_commend.text == '沒有評論':
                dataset.append([id, name.text, 0, 0, shop_class[0].text])
                continue

            # 星數
            star = elm.find_element(
                By.CSS_SELECTOR,
                'span.MW4etd'
            )

            # 評論數
            comment_num = elm.find_element(
                By.CSS_SELECTOR,
                'span.UY7F9'
            )

            regex_comment = r"\w+"  # (60) => 60
            comment_num_re = re.search(regex_comment, comment_num.text)

            # 資料匯入list
            dataset.append([id, name.text, eval(star.text), eval(comment_num_re[0]), shop_class[0].text])
    except Exception as e:
        print('google_map_error')


    # 取得各店家連結、經緯度    
    list_links = [] # 存放店家連結
    
    try:
        links = driver.find_elements(
            By.CSS_SELECTOR,
            'a.hfpxzc'
        )

        id = 0

        for lelm in links:
            # 店家連結
            id += 1
            link = lelm.get_attribute('href')
            list_links.append(link)

            # coordinate(經緯度)
            regex_coordinate = r"(?<=!3d).*(?=!16s)"  # link => 25.0266645!4d121.5431999
            search_coordinate = re.search(regex_coordinate, link)
            
            if search_coordinate:
                # 經緯度加入list
                coordinate = search_coordinate[0].replace('!4d', ',')  # coordinate:座標(經緯度)     
                dataset[id].append(coordinate)
            else:
                dataset[id].append('沒有座標')
        
    except Exception as e:
        print('No_links_and_coordinate')


    # 進入店家連結取得詳細資料
    id = 0
    for url in list_links:
        try:
            driver.get(url)

            # 強制休息
            sleep(random.randrange(4))
            
            id += 1

            # 詳細地址
            # address = driver.find_element(
            #     By.CSS_SELECTOR,
            #     'div.Io6YTe.fontBodyMedium.kR99db '
            # )
            address = WebDriverWait(driver, 10).until(
            EC.presence_of_element_located(
                (By.CSS_SELECTOR, "div.Io6YTe.fontBodyMedium.kR99db"))
            )

            regex_address = r'[^0-9].*'  # 106台北市大安區復興南路二段206號 => 台北市大安區復興南路二段206號
            search_address = re.search(regex_address, address.text)
            
            if search_address:
                # 加入list
                dataset[id].append(search_address[0])
            else:
                dataset[id].append('沒有地址')
        
        except Exception as e:
            dataset[id].append('沒有地址')
            print(f'{id},No_address')
            continue
    
    return dataset

    
    

def to_csv(search_name, dataset):
    # 將 list 存成 csv
    with open(f"./{search_name}.csv", "w", newline='', encoding="utf-8-sig") as file:
        w = csv.writer(file)
        # 寫入二維表格
        w.writerows(dataset)
        print(f'{search_name}-ending...')

def listening():
    global switch

    while switch:
        # 睡一下
        sleep(0.01)

        #自動清除此格的文字輸出
        clear_output(wait=True)

        try:
            # 取得 Box 物件
            btn_reload = pyautogui.locateOnScreen(
                './reload.png',
                confidence=0.9 # opencv信心指數，用 1 的話圖片一點灰塵污漬都不能有 
            )

            btn_reload_point = pyautogui.center(btn_reload)

            # 按下 重新載入
            pyautogui.click(btn_reload_point.x, btn_reload_point.y)
        except:
            pass

if __name__ == "__main__":
    driver = initialize_browser()
    switch = True
    listening_thread = threading.Thread(target=listening) # 建立listening執行緒
    listening_thread.start() # 啟動執行緒

    with open(r'./dist_test.txt', 'r', encoding='utf-8') as file:
        dist_list = file.read().split('、')  # 行政區
        for search_name in dist_list:
            input_name(driver, search_name)
            scroll(driver)
            dataset = scraping(driver)
            to_csv(search_name, dataset)
            
    switch = False # 爬蟲結束，結束迴圈
    listening_thread.join() # 结束執行緒
    
    driver.quit()

# %%
# 操作 browser 的 API
from selenium.webdriver.chrome.service import Service
from selenium import webdriver

# 處理逾時例外的工具
from selenium.common.exceptions import TimeoutException

# 面對動態網頁，等待某個元素出現的工具，通常與 exptected_conditions 搭配
from selenium.webdriver.support.ui import WebDriverWait

# 搭配 WebDriverWait 使用，對元素狀態的一種期待條件，若條件發生，則等待結束，往下一行執行
from selenium.webdriver.support import expected_conditions as EC

# 期待元素出現要透過什麼方式指定，通常與 EC、WebDriverWait 一起使用
from selenium.webdriver.common.by import By

# 強制等待 (執行期間休息一下)
from time import sleep

import csv

# send_keys模擬鍵盤輸入
from selenium.webdriver.common.keys import Keys

import random

import re

# listening
import pyautogui
from time import sleep, time
import keyboard
from IPython.display import clear_output

# 多執行緒
import threading




# 啟動瀏覽器工具的選項
my_options = webdriver.ChromeOptions()
# my_options.add_argument("--headless")                #不開啟實體瀏覽器背景執行
my_options.add_argument("--start-maximized")         #最大化視窗
my_options.add_argument("--incognito")               #開啟無痕模式
my_options.add_argument("--disable-popup-blocking") #禁用彈出攔截
my_options.add_argument("--disable-notifications")  #取消 chrome 推播通知
my_options.add_argument("--lang=zh-TW")  #設定為正體中文

# 使用 Chrome 的 WebDriver
driver = webdriver.Chrome(
    options = my_options
)


search_name = '鶯歌'

# 前往google_map網站
driver.get('https://www.google.com/maps?authuser=0')

# 尋找網頁中的搜尋框
input_block = driver.find_element(
    By.CSS_SELECTOR,
    'input.searchboxinput.xiQnY'
)
print(f'{search_name}-starting...')
# 在搜尋框中輸入文字
input_block.send_keys(f'{search_name} 火車站')
sleep(0.1)
input_block.send_keys(Keys.ENTER)
sleep(0.5)

# 取得google_map基本內容
# elements = driver.find_elements(
#     By.CSS_SELECTOR,
#     'div.lMbq3e'
# )

elements = WebDriverWait(driver, 10).until(
            EC.presence_of_element_located(
                (By.CSS_SELECTOR, "div.lMbq3e"))
            )

print(elements)

for elm in elements:
    # 店家id
    id += 1

    # 店家名稱
    name = elm.find_element(
        By.CSS_SELECTOR,
        'h1.DUwDvf.lfPIob'
    )
    print(name.text)
    # # 店家種類
    # shop_class = elm.find_elements(
    #     By.CSS_SELECTOR,
    #     'div.W4Efsd > div.W4Efsd > span'
    # )
# Out:
# 鶯歌-starting...
# []

# %%
# 取得google_map基本內容
element = driver.find_element(
    By.CSS_SELECTOR,
    'div.lMbq3e'
)

dataset = [['name', 'class', 'address', 'latitude', 'longitude']]

# 車站名稱
name = element.find_element(
    By.CSS_SELECTOR,
    'h1.DUwDvf.lfPIob'
)


# 設施種類
class_ = element.find_element(
    By.CSS_SELECTOR,
    'button.DkEaL '
)


# 車站地址
address = driver.find_element(
    By.CSS_SELECTOR,
    'div.Io6YTe.fontBodyMedium.kR99db'
)

regex_address = r'[^0-9].*'  # 106台北市大安區復興南路二段206號 => 台北市大安區復興南路二段206號
search_address = re.search(regex_address, address.text)


# coordinate(經緯度)
link = driver.current_url # 當前網頁網址
regex_coordinate = r"(?<=!3d).*(?=!16s)"  # link => 25.0266645!4d121.5431999
search_coordinate = re.search(regex_coordinate, link)
# 切分成緯度、經度
coordinate = search_coordinate[0].split('!4d')  # coordinate:座標(經緯度) 

dataset.append([name.text, class_.text, search_address[0], coordinate[0], coordinate[1]])
# Out:
# [['name', 'class', 'address', 'latitude', 'longitude'], ['鶯歌火車站', '火車站', '新北市鶯歌區文化路68-1號', '24.9545594', '121.3551137']]

# %%
# 操作 browser 的 API
from selenium.webdriver.chrome.service import Service
from selenium import webdriver

# 處理逾時例外的工具
from selenium.common.exceptions import TimeoutException

# 面對動態網頁，等待某個元素出現的工具，通常與 exptected_conditions 搭配
from selenium.webdriver.support.ui import WebDriverWait

# 搭配 WebDriverWait 使用，對元素狀態的一種期待條件，若條件發生，則等待結束，往下一行執行
from selenium.webdriver.support import expected_conditions as EC

# 期待元素出現要透過什麼方式指定，通常與 EC、WebDriverWait 一起使用
from selenium.webdriver.common.by import By

# 強制等待 (執行期間休息一下)
from time import sleep

import csv

# send_keys模擬鍵盤輸入
from selenium.webdriver.common.keys import Keys

import random

import re

# listening
import pyautogui
from time import sleep, time
import keyboard
from IPython.display import clear_output

# 多執行緒
import threading



def initialize_browser():
    # 啟動瀏覽器工具的選項
    my_options = webdriver.ChromeOptions()
    # my_options.add_argument("--headless")                #不開啟實體瀏覽器背景執行
    my_options.add_argument("--start-maximized")         #最大化視窗
    my_options.add_argument("--incognito")               #開啟無痕模式
    my_options.add_argument("--disable-popup-blocking") #禁用彈出攔截
    my_options.add_argument("--disable-notifications")  #取消 chrome 推播通知
    my_options.add_argument("--lang=zh-TW")  #設定為正體中文

    # 使用 Chrome 的 WebDriver
    driver = webdriver.Chrome(
        options = my_options
    )

    return driver


def scraping(driver):
    with open(r'./雙北火車站.txt', 'r', encoding='utf-8') as file:
        dist_list = file.readlines()
        dataset = [['name', 'class', 'address', 'latitude', 'longitude']]
        
        for search_name in dist_list:
            search_name = search_name.replace('\n','')
            
            # 前往google_map網站
            driver.get('https://www.google.com/maps?authuser=0')
        
            # 尋找網頁中的搜尋框
            input_block = driver.find_element(
                By.CSS_SELECTOR,
                'input.searchboxinput.xiQnY'
            )
            print(f'{search_name}-starting...')
            # 在搜尋框中輸入文字
            input_block.send_keys(f'{search_name}火車站')
            sleep(0.1)
            input_block.send_keys(Keys.ENTER)
            sleep(0.5)
        
            try:
                # 取得google_map基本內容
                element = WebDriverWait(driver, 10).until(
                            EC.presence_of_element_located(
                            (By.CSS_SELECTOR, "div.lMbq3e"))
                            )
                

            
                # 車站名稱
                name = element.find_element(
                    By.CSS_SELECTOR,
                    'h1.DUwDvf.lfPIob'
                )
            
            
                # 設施種類
                class_ = element.find_element(
                    By.CSS_SELECTOR,
                    'button.DkEaL '
                )
            
            
                # 車站地址
                address = driver.find_element(
                    By.CSS_SELECTOR,
                    'div.Io6YTe.fontBodyMedium.kR99db'
                )
            
                regex_address = r'[^0-9].*'  # 106台北市大安區復興南路二段206號 => 台北市大安區復興南路二段206號
                search_address = re.search(regex_address, address.text)
            
            
                # coordinate(經緯度)
                link = driver.current_url # 當前網頁網址
                regex_coordinate = r"(?<=!3d).*(?=!16s)"  # link => 25.0266645!4d121.5431999
                search_coordinate = re.search(regex_coordinate, link)
                # 切分成緯度、經度
                coordinate = search_coordinate[0].split('!4d')  # coordinate:座標(經緯度) 
            
                dataset.append([name.text, class_.text, search_address[0], coordinate[0], coordinate[1]])

                    
            except:  
                try:
                    search_block = WebDriverWait(driver, 10).until(
                            EC.presence_of_element_located(
                            (By.CSS_SELECTOR, "a.hfpxzc"))
                            )
                                
                    search_block.click()
    
                    # 車站名稱
                    name = element.find_element(
                        By.CSS_SELECTOR,
                        'h1.DUwDvf.lfPIob'
                    )
                
                
                    # 設施種類
                    class_ = element.find_element(
                        By.CSS_SELECTOR,
                        'button.DkEaL '
                    )
                
                
                    # 車站地址
                    address = driver.find_element(
                        By.CSS_SELECTOR,
                        'div.Io6YTe.fontBodyMedium.kR99db'
                    )
                
                    regex_address = r'[^0-9].*'  # 106台北市大安區復興南路二段206號 => 台北市大安區復興南路二段206號
                    search_address = re.search(regex_address, address.text)
                
                
                    # coordinate(經緯度)
                    link = driver.current_url # 當前網頁網址
                    regex_coordinate = r"(?<=!3d).*(?=!16s)"  # link => 25.0266645!4d121.5431999
                    search_coordinate = re.search(regex_coordinate, link)
                    # 切分成緯度、經度
                    coordinate = search_coordinate[0].split('!4d')  # coordinate:座標(經緯度) 
                
                    dataset.append([name.text, class_.text, search_address[0], coordinate[0], coordinate[1]])
                except:
                    print(search_name + 'null')
                    continue
                
                


    
    

def to_csv(search_name, dataset):
    # 將 list 存成 csv
    with open(f"./雙北火車站.csv", "w", newline='', encoding="utf-8-sig") as file:
        w = csv.writer(file)
        # 寫入二維表格
        w.writerows(dataset)
        print(f'{search_name}-ending...')

def listening():
    global switch

    while switch:
        # 睡一下
        sleep(0.01)

        #自動清除此格的文字輸出
        clear_output(wait=True)

        try:
            # 取得 Box 物件
            btn_reload = pyautogui.locateOnScreen(
                './reload.png',
                confidence=0.9 # opencv信心指數，用 1 的話圖片一點灰塵污漬都不能有 
            )

            btn_reload_point = pyautogui.center(btn_reload)

            # 按下 重新載入
            pyautogui.click(btn_reload_point.x, btn_reload_point.y)
        except:
            pass

if __name__ == "__main__":
    driver = initialize_browser()
    switch = True
    listening_thread = threading.Thread(target=listening) # 建立listening執行緒
    listening_thread.start() # 啟動執行緒


    dataset = scraping(driver)
    to_csv(search_name, dataset)
    
    switch = False # 爬蟲結束，結束迴圈
    listening_thread.join() # 结束執行緒
    
    driver.quit()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[65], line 214
#     210 listening_thread = threading.Thread(target=listening) # 建立listening執行緒
#     211 listening_thread.start() # 啟動執行緒
# --> 214 dataset = scraping(driver)
#     215 to_csv(search_name, dataset)
#     217 switch = False # 爬蟲結束，結束迴圈
#
# Cell In[65], line 76, in scraping(driver)
#      74 print(f'{search_name}-starting...')
#      75 # 在搜尋框中輸入文字
# ---> 76 input_block.send_keys(f'{search_name}火車站')
#      77 sleep(0.1)
#      78 input_block.send_keys(Keys.ENTER)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\selenium\webdriver\remote\webelement.py:230, in WebElement.send_keys(self, *value)
#     227             remote_files.append(self._upload(file))
#     228         value = "\n".join(remote_files)
# --> 230 self._execute(
#     231     Command.SEND_KEYS_TO_ELEMENT, {"text": "".join(keys_to_typing(value)), "value": keys_to_typing(value)}
#     232 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\selenium\webdriver\remote\webelement.py:394, in WebElement._execute(self, command, params)
#     392     params = {}
#     393 params["id"] = self._id
# --> 394 return self._parent.execute(command, params)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~\AppData\Roaming\Python\Python310\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: target frame detached
#   (failed to check if window was closed: disconnected: not connected to DevTools)
#   (Session info: chrome=121.0.6167.140)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7BA0D5E42+3538674]
# 	(No symbol) [0x00007FF7B9CF4C02]
# 	(No symbol) [0x00007FF7B9BA599D]
# 	(No symbol) [0x00007FF7B9B92D43]
# 	(No symbol) [0x00007FF7B9B913A5]
# 	(No symbol) [0x00007FF7B9B91E5F]
# 	(No symbol) [0x00007FF7B9B9F32E]
# 	(No symbol) [0x00007FF7B9BB2044]
# 	(No symbol) [0x00007FF7B9C2BF33]
# 	(No symbol) [0x00007FF7B9C0EE53]
# 	(No symbol) [0x00007FF7B9BDF514]
# 	(No symbol) [0x00007FF7B9BE0631]
# 	GetHandleVerifier [0x00007FF7BA106CAD+3738973]
# 	GetHandleVerifier [0x00007FF7BA15C506+4089270]
# 	GetHandleVerifier [0x00007FF7BA154823+4057299]
# 	GetHandleVerifier [0x00007FF7B9E25C49+720121]
# 	(No symbol) [0x00007FF7B9D0126F]
# 	(No symbol) [0x00007FF7B9CFC304]
# 	(No symbol) [0x00007FF7B9CFC432]
# 	(No symbol) [0x00007FF7B9CEBD04]
# 	BaseThreadInitThunk [0x00007FFE582F7344+20]
# 	RtlUserThreadStart [0x00007FFE585626B1+33]

# %%
elements = WebDriverWait(driver, 10).until(
            EC.presence_of_element_located(
                (By.CSS_SELECTOR, "div.lMbq3e"))
            )

print(elements)


# 車站名稱
name = elements.find_element(
    By.CSS_SELECTOR,
    'h1.DUwDvf.lfPIob'
)


# 設施種類
class_ = elements.find_element(
    By.CSS_SELECTOR,
    'button.DkEaL '
)


# 車站地址
address = driver.find_element(
    By.CSS_SELECTOR,
    'div.Io6YTe.fontBodyMedium.kR99db'
)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="902efa2be4ff6fe0b54b9d2fb113ab05", element="536EDFFD8BE6F03C60E28128D7B7E421_element_74")>

# %%
search_block = driver.find_element(
    By.CSS_SELECTOR,
    'a.hfpxzc'
)

search_block.click()

elements = WebDriverWait(driver, 10).until(
            EC.presence_of_element_located(
                (By.CSS_SELECTOR, "div.lMbq3e"))
            )

print(elements)


# 車站名稱
name = elements.find_element(
    By.CSS_SELECTOR,
    'h1.DUwDvf.lfPIob'
)


# 設施種類
class_ = elements.find_element(
    By.CSS_SELECTOR,
    'button.DkEaL '
)


# 車站地址
address = driver.find_element(
    By.CSS_SELECTOR,
    'div.Io6YTe.fontBodyMedium.kR99db'
)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="7d0c412eee6d612f639f29da37ccd531", element="2CDD2C6E5DC72A24FFB73199098F384F_element_1760")>

# %%
search_block = WebDriverWait(driver, 10).until(
                            EC.presence_of_element_located(
                            (By.CSS_SELECTOR, "a.hfpxzc"))
                            )
                                
search_block.click()
